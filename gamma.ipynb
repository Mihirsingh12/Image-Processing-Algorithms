# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
img=mpimg.imread('aerial3.jpg')
x=img[:,:,0]
plt.imshow(x,cmap="gray")
plt.show()
y=np.zeros(np.shape(x))
t1=list(np.shape(x))
y=255*((x/255)**0.5)
plt.imshow(y,cmap="gray")
plt.show()
