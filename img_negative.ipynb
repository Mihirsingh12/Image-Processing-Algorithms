# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
img=mpimg.imread('digitalmammo.jpg')
x=img[:,:,0]
plt.imshow(x,cmap="gray")
plt.show()
y=np.zeros(np.shape(x))
y=255-x
plt.imshow(y,cmap="gray")
plt.show()
